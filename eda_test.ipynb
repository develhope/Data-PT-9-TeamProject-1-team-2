# %%
import pandas as pd

df  = pd.read_csv('online_gaming_behavior_dataset.csv')
df.head(20)
# Out:
#     PlayerID  Age  Gender Location   GameGenre  PlayTimeHours  \
# 0       9000   43    Male    Other    Strategy      16.271119
# 1       9001   29  Female      USA    Strategy       5.525961
# 2       9002   22  Female      USA      Sports       8.223755
# 3       9003   35    Male      USA      Action       5.265351
# 4       9004   33    Male   Europe      Action      15.531945
# 5       9005   37    Male   Europe         RPG      20.561855
# 6       9006   25    Male      USA      Action       9.752716
# 7       9007   25  Female     Asia         RPG       4.401729
# 8       9008   38  Female   Europe  Simulation      18.152733
# 9       9009   38  Female    Other      Sports      23.942772
# 10      9010   17    Male      USA    Strategy       4.829916
# 11      9011   36  Female     Asia  Simulation       5.535981
# 12      9012   16    Male      USA      Sports      18.776234
# 13      9013   38  Female      USA    Strategy       8.701959
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   40034 non-null  int64
#  1   Age                        40034 non-null  int64
#  2   Gender                     40034 non-null  object
#  3   Location                   40034 non-null  object
#  4   GameGenre                  40034 non-null  object
#  5   PlayTimeHours              40034 non-null  float64
#  6   InGamePurchases            40034 non-null  int64
#  7   GameDifficulty             40034 non-null  object
#  8   SessionsPerWeek            40034 non-null  int64
#  9   AvgSessionDurationMinutes  40034 non-null  int64
#  10  PlayerLevel                40034 non-null  int64
#  11  AchievementsUnlocked       40034 non-null  int64
#  12  EngagementLevel            40034 non-null  object
# ...

# %%
df.describe()
# Out:
#            PlayerID           Age  PlayTimeHours  InGamePurchases  \
# count  40034.000000  40034.000000   40034.000000     40034.000000
# mean   29016.500000     31.992531      12.024365         0.200854
# std    11556.964675     10.043227       6.914638         0.400644
# min     9000.000000     15.000000       0.000115         0.000000
# 25%    19008.250000     23.000000       6.067501         0.000000
# 50%    29016.500000     32.000000      12.008002         0.000000
# 75%    39024.750000     41.000000      17.963831         0.000000
# max    49033.000000     49.000000      23.999592         1.000000
#
#        SessionsPerWeek  AvgSessionDurationMinutes   PlayerLevel  \
# count     40034.000000               40034.000000  40034.000000
# mean          9.471774                  94.792252     49.655568
# std           5.763667                  49.011375     28.588379
# min           0.000000                  10.000000      1.000000
# ...

# %%
df.hist(figsize=(20,8),bins=30,edgecolor="black")
# Out:
# array([[<Axes: title={'center': 'PlayerID'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'PlayTimeHours'}>],
#        [<Axes: title={'center': 'InGamePurchases'}>,
#         <Axes: title={'center': 'SessionsPerWeek'}>,
#         <Axes: title={'center': 'AvgSessionDurationMinutes'}>],
#        [<Axes: title={'center': 'PlayerLevel'}>,
#         <Axes: title={'center': 'AchievementsUnlocked'}>, <Axes: >]],
#       dtype=object)

# %%
medium_players_age = df[(df['EngagementLevel'] == 'Medium') &( df['Age']==43)]
medium_players_age
# Out:
#        PlayerID  Age  Gender Location   GameGenre  PlayTimeHours  \
# 0          9000   43    Male    Other    Strategy      16.271119
# 219        9219   43  Female     Asia    Strategy      18.682071
# 256        9256   43  Female     Asia  Simulation       8.012559
# 284        9284   43    Male      USA      Sports       3.840849
# 345        9345   43  Female     Asia  Simulation       1.623975
# ...         ...  ...     ...      ...         ...            ...
# 39771     48771   43    Male      USA      Sports      23.545475
# 39859     48859   43  Female      USA         RPG      10.312043
# 39890     48890   43    Male   Europe         RPG       4.862955
# 39972     48972   43    Male      USA    Strategy      15.128764
# 40021     49021   43    Male     Asia      Action       6.146619
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 0                    0         Medium                6
# 219                  0           Easy                4
# ...
